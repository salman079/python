# %% [markdown]
# # Interacting with Web APIs

# %%
import pandas as pd
import requests

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39189',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39189/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39189/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39189/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39189',
#   'id': 787001863,
#   'node_id': 'MDU6SXNzdWU3ODcwMDE4NjM=',
#   'number': 39189,
#   'title': 'BUG: queries on categorical string columns in read_hdf return unexpected results',
#   'user': {'login': 'travispavletich',
#    'id': 22419093,
#    'node_id': 'MDQ6VXNlcjIyNDE5MDkz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22419093?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/travispavletich',
#    'html_url': 'https://github.com/travispavletich',
#    'followers_url': 'https://api.github.com/users/travispavletich/followers',
#    'following_url': 'https://api.github.com/users/travispavletich/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/travispavletich/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/travispavletich/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/travispavletich/subscriptions',
#    'organizations_url': 'https://api.github.com/users/travispavletich/orgs',
#    'repos_url': 'https://api.github.com/users/travispavletich/repos',
#    'events_url': 'https://api.github.com/users/travispavletich/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/travispavletich/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-15T15:57:44Z',
#   'updated_at': '2021-01-15T15:57:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nh5_path = \'test.h5\'\r\ndf = pd.DataFrame({\'col\': [\'a\', \'b\', \'s\']})\r\ncategorical_values = list(sorted(list(df.col.unique()))) # sorted because of https://github.com/pandas-dev/pandas/issues/16623\r\nmax_widths = {\'col\': 1} # will also set this column to be a "data column"\r\ndf.col = df.col.astype(\'category\')\r\ndf.col.cat.set_categories(categorical_values, inplace=True)\r\ndf.to_hdf(h5_path, \'main\', mode=\'a\', format=\'table\', append=True, min_itemsize=max_widths)\r\n\r\nread_df = pd.read_hdf(h5_path, where=\'col == "q"\') #returns df with index=2, col = s \r\n```\r\n\r\n```python\r\nh5_path = \'test.h5\'\r\ndf = pd.DataFrame({\'col\': [\'Word\', \'Test\']})\r\ncategorical_values = list(sorted(list(df.col.unique())))\r\nmax_widths = {\'col\': 4}\r\ndf.col = df.col.astype(\'category\')\r\ndf.col.cat.set_categories(categorical_values, inplace=True)\r\ndf.to_hdf(h5_path, \'main\', mode=\'a\', format=\'table\', append=True, min_itemsize=max_widths)\r\n\r\nread_df = pd.read_hdf(h5_path, where=\'col == "W"\') #returns df with index=0, col=Word\r\nread_df = pd.read_hdf(h5_path, where=\'col == "T"\') # returns empty df (as expected)\r\n```\r\n\r\n#### Problem description\r\nThe output here is completely incorrect. These where clauses are returning non-sensical results for values that don\'t exist within the dataframe. I should note that I have not seen issues with querying for values that are present in the dataframe however.\r\n\r\n#### Expected Output\r\n\r\nFor all read_hdf calls, the expected output is an empty dataframe.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.7.9.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 3.10.0-514.21.2.el7.x86_64\r\nVersion          : #1 SMP Tue Jun 20 12:24:47 UTC 2017\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.2\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 20.2.4\r\nsetuptools       : 50.3.0.post20201006\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : 2.7.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39188',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39188/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39188/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39188/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39188',
#   'id': 786972726,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTU1NzYzMTY2',
#   'number': 39188,
#   'title': 'REGR: Different results from DataFrame.apply and str accessor',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/81',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/81',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/81/labels',
#    'id': 6207963,
#    'node_id': 'MDk6TWlsZXN0b25lNjIwNzk2Mw==',
#    'number': 81,
#    'title': '1.2.1',
#    'description': 'on-merge: backport to 1.2.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 18,
#    'closed_issues': 95,
#    'state': 'open',
#    'created_at': '2020-12-13T17:06:11Z',
#    'updated_at': '2021-01-15T15:21:15Z',
#    'due_on': '2021-01-18T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-15T15:17:31Z',
#   'updated_at': '2021-01-15T15:29:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39188',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39188',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39188.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39188.patch'},
#   'body': '- [ ] closes #38979\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\n\r\n@jbrockmendel despite my comment https://github.com/pandas-dev/pandas/issues/38979#issuecomment-760470446, I had no joy trying to locate the caching issue.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39186',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39186/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39186/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39186/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39186',
#   'id': 786849849,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTU1NjYxMDE0',
#   'number': 39186,
#   'title': 'REF: extract classes in pandas/core/describe.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-15T12:12:34Z',
#   'updated_at': '2021-01-15T15:28:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39186',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39186',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39186.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39186.patch'},
#   'body': '- [ ] xref #36833\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nExtract classes ``SeriesDescriber`` and ``DataFrameDescriber``.\r\nIn the next steps I am going to enable strategy pattern and move corresponding describe functions to the concrete strategy classes (for each datatype).',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39185',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39185/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39185/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39185/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39185',
#   'id': 786670488,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTU1NTExNDgy',
#   'number': 39185,
#   'title': 'DOC: set the documentation language',
#   'user': {'login': 'afeld',
#    'id': 86842,
#    'node_id': 'MDQ6VXNlcjg2ODQy',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/86842?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afeld',
#    'html_url': 'https://github.com/afeld',
#    'followers_url': 'https://api.github.com/users/afeld/followers',
#    'following_url': 'https://api.github.com/users/afeld/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/afeld/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/afeld/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/afeld/subscriptions',
#    'organizations_url': 'https://api.github.com/users/afeld/orgs',
#    'repos_url': 'https://api.github.com/users/afeld/repos',
#    'events_url': 'https://api.github.com/users/afeld/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/afeld/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-15T07:22:26Z',
#   'updated_at': '2021-01-15T07:26:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39185',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39185',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39185.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39185.patch'},
#   'body': 'Ensures the language is specified in the generated HTML. [Documentation on the configuration option.](https://www.sphinx-doc.org/en/master/usage/configuration.html#confval-language)\r\n\r\nBefore:\r\n\r\n```\r\n$ curl -s https://pandas.pydata.org/docs/dev/getting_started/comparison/comparison_with_spreadsheets.html | grep "<html"\r\n<html>\r\n```\r\n\r\nAfter:\r\n\r\n```\r\n$ python make.py --single getting_started/comparison/comparison_with_spreadsheets.rst\r\n$ grep "<html" build/html/getting_started/comparison/comparison_with_spreadsheets.html \r\n<html lang="en">\r\n```\r\n\r\n- [ ] ~~closes #xxxx~~\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] ~~whatsnew entry~~\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39184',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39184/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39184/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39184/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39184',
#   'id': 786568460,
#   'node_id': 'MDU6SXNzdWU3ODY1Njg0NjA=',
#   'number': 39184,
#   'title': 'BUG: Numpy np.[op](df1, df2) regression in pandas 1.2.0',
#   'user': {'login': 'WhistleWhileYouWork',
#    'id': 39565956,
#    'node_id': 'MDQ6VXNlcjM5NTY1OTU2',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/39565956?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WhistleWhileYouWork',
#    'html_url': 'https://github.com/WhistleWhileYouWork',
#    'followers_url': 'https://api.github.com/users/WhistleWhileYouWork/followers',
#    'following_url': 'https://api.github.com/users/WhistleWhileYouWork/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WhistleWhileYouWork/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WhistleWhileYouWork/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WhistleWhileYouWork/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WhistleWhileYouWork/orgs',
#    'repos_url': 'https://api.github.com/users/WhistleWhileYouWork/repos',
#    'events_url': 'https://api.github.com/users/WhistleWhileYouWork/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WhistleWhileYouWork/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/81',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/81',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/81/labels',
#    'id': 6207963,
#    'node_id': 'MDk6TWlsZXN0b25lNjIwNzk2Mw==',
#    'number': 81,
#    'title': '1.2.1',
#    'description': 'on-merge: backport to 1.2.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 18,
#    'closed_issues': 95,
#    'state': 'open',
#    'created_at': '2020-12-13T17:06:11Z',
#    'updated_at': '2021-01-15T15:21:15Z',
#    'due_on': '2021-01-18T08:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-01-15T05:41:59Z',
#   'updated_at': '2021-01-15T16:05:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n\r\n#### Code Sample\r\n\r\n```python\r\ndf = pd.DataFrame({k: [1,2,3,4,5] for k in 'abcd'})\r\nnp.add(df[['a', 'b']], df[['c', 'd']])\r\n```\r\n\r\n#### Problem description\r\n\r\nThis is a regression from pandas 1.1.5 (both versions are using numpy 1.19.5).\r\n\r\nNormally if we want to add, subtract, multiply or divide df columns with different names we get NaNs because the column names don't match. E.g:\r\n```python\r\n>>> df[['a', 'b']] + df[['c', 'd']]\r\n    a   b   c   d\r\n0 NaN NaN NaN NaN\r\n1 NaN NaN NaN NaN\r\n2 NaN NaN NaN NaN\r\n3 NaN NaN NaN NaN\r\n4 NaN NaN NaN NaN\r\n```\r\n\r\nTo get around this, we would use np.[op](df1, df2).\r\nHowever, we get the same output as above.\r\n```python\r\n>>> np.add(df[['a', 'b']], df[['c', 'd']])\r\n    a   b   c   d\r\n0 NaN NaN NaN NaN\r\n1 NaN NaN NaN NaN\r\n2 NaN NaN NaN NaN\r\n3 NaN NaN NaN NaN\r\n4 NaN NaN NaN NaN\r\n```\r\n\r\n\r\n\r\n#### Expected Output\r\n\r\n```python\r\n# Using pandas 1.1.5:\r\n>>> np.add(df[['a', 'b']], df[['c', 'd']])\r\n    a   b\r\n0   2   2\r\n1   4   4\r\n2   6   6\r\n3   8   8\r\n4  10  10\r\n```\r\n\r\n#### Temporary solution\r\n```python\r\n# This may have a potential copy penalty with the conversion to numpy\r\n>>> df[['a', 'b']] + df[['c', 'd']].to_numpy()\r\n    a   b\r\n0   2   2\r\n1   4   4\r\n2   6   6\r\n3   8   8\r\n4  10  10\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.9.1.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.5\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n</details>\r\n\r\n Just my 2 cents: I was more than willing to test this on a nightly / master release, but it doesn't appear you release those. It could be quite beneficial to publish nightlies to PyPl so we don't report issues that have already been fixed. For some, it might be easier to test a nightly than peruse recent open and closed issues.",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39183',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39183/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39183/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39183/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39183',
#   'id': 786536282,
#   'node_id': 'MDU6SXNzdWU3ODY1MzYyODI=',
#   'number': 39183,
#   'title': 'January 2021 Docs Meeting',
#   'user': {'login': 'afeld',
#    'id': 86842,
#    'node_id': 'MDQ6VXNlcjg2ODQy',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/86842?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afeld',
#    'html_url': 'https://github.com/afeld',
#    'followers_url': 'https://api.github.com/users/afeld/followers',
#    'following_url': 'https://api.github.com/users/afeld/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/afeld/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/afeld/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/afeld/subscriptions',
#    'organizations_url': 'https://api.github.com/users/afeld/orgs',
#    'repos_url': 'https://api.github.com/users/afeld/repos',
#    'events_url': 'https://api.github.com/users/afeld/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/afeld/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2187005593,
#     'node_id': 'MDU6TGFiZWwyMTg3MDA1NTkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Community',
#     'name': 'Community',
#     'color': '0bbec4',
#     'default': False,
#     'description': 'Community topics (meetings, etc.)'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-01-15T05:02:57Z',
#   'updated_at': '2021-01-15T14:54:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "It was mentioned at the Developer Meeting (https://github.com/pandas-dev/pandas/issues/39125) that there would be interest in having a meeting specifically focused on documentation. I hope the core team doesn't mind me pushing ahead on that 😄 \r\n\r\nPlease [**provide your availability**](https://doodle.com/poll/m46rp3ngx8f7sd62?utm_source=poll&utm_medium=link) in the next few days so we can find a time that works for the most people. Will comment with the date and Zoom link once finalized. All are welcome.\r\n\r\n[Agenda/notes doc](https://docs.google.com/document/d/1JoiqTdK6gi5W1QiTWrqtTV-rNmIqU3xROgHY5iT4J5g/edit#) — feel free to add things in advance. Thanks!\r\n\r\n@pandas-dev/pandas-core @pandas-dev/pandas-triage @pandas-dev/pydata-sphinx-theme @bollwyvl ",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39182',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39182/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39182/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39182/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39182',
#   'id': 786510994,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTU1MzY3MjA4',
#   'number': 39182,
#   'title': 'CI/DOC: Add option to build whatsnew',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'},
#    {'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-15T03:51:04Z',
#   'updated_at': '2021-01-15T04:19:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39182',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39182',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39182.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39182.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nAdds the option to compile the whatsnew. It also builds the API (to resolve links) and opens the whatsnew page in a browser when complete. This is the most frequent reason why I build the docs, and cuts down build time by 40% on my machine.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39181',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39181/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39181/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39181/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39181',
#   'id': 786424240,
#   'node_id': 'MDU6SXNzdWU3ODY0MjQyNDA=',
#   'number': 39181,
#   'title': 'BUG: ExcelWriter.book --> no member ->Slow Execution Time<-',
#   'user': {'login': 'Eric106',
#    'id': 24252112,
#    'node_id': 'MDQ6VXNlcjI0MjUyMTEy',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/24252112?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Eric106',
#    'html_url': 'https://github.com/Eric106',
#    'followers_url': 'https://api.github.com/users/Eric106/followers',
#    'following_url': 'https://api.github.com/users/Eric106/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Eric106/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Eric106/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Eric106/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Eric106/orgs',
#    'repos_url': 'https://api.github.com/users/Eric106/repos',
#    'events_url': 'https://api.github.com/users/Eric106/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Eric106/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-14T23:49:52Z',
#   'updated_at': '2021-01-15T02:49:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [*] I have checked that this issue has not already been reported.\r\n\r\n- [*] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [*] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\n# Your code here\r\n\r\nwriter = ExcelWriter(# pylint: disable=abstract-class-instantiated\r\n        path=fileName, engine=\'xlsxwriter\')  \r\n    workbook = writer.book # pylint: disable=no-member\r\n    header_format = workbook.add_format({\'bold\': True, \'align\': \'center\',\r\n                                         \'fg_color\': \'#80bfff\', \'border\': 2,\r\n                                          \'font_name\': \'Times New Roman\', \'font_size\': 9})\r\n\r\n#### Problem description\r\nthe pylint detects that ExcelWriter don\'t have "book" member, but the code works well just have \r\na very bad execution time in comparison with the 1.1.5 Pandas version \r\n\r\n#### Expected Output\r\nSave DataFrames in the same file but in different sheets.\r\nExpected time: 30 sec   (pandas==1.1.5)\r\nCurrent time: 90 sec    (pandas==1.2.0)\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.8.6.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19041\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : Spanish_Mexico.1252\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.1\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 49.2.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 3.2.1\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.3.7\r\nlxml.etree       : 4.6.2\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.18.1\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.1\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.5\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.5.4\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.7\r\nxarray           : None\r\nxlrd             : 1.2.0\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39178',
#   'id': 786362353,
#   'node_id': 'MDU6SXNzdWU3ODYzNjIzNTM=',
#   'number': 39178,
#   'title': "BUG: MultiIndexes are disappearing using an empty dataframe, Groupby and aggregate using 'list' method",
#   'user': {'login': 'natanvotre',
#    'id': 19258773,
#    'node_id': 'MDQ6VXNlcjE5MjU4Nzcz',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/19258773?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natanvotre',
#    'html_url': 'https://github.com/natanvotre',
#    'followers_url': 'https://api.github.com/users/natanvotre/followers',
#    'following_url': 'https://api.github.com/users/natanvotre/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natanvotre/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natanvotre/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natanvotre/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natanvotre/orgs',
#    'repos_url': 'https://api.github.com/users/natanvotre/repos',
#    'events_url': 'https://api.github.com/users/natanvotre/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natanvotre/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-14T21:44:49Z',
#   'updated_at': '2021-01-14T21:49:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\nThis bug is happening just in the pandas' version 1.2.0. The indexes are disappearing in the following condition:\r\n- Using MultiIndex;\r\n- Using an empty dataframe;\r\n- GroupBy the empty dataframe with multi indexes;\r\n- Aggregate using the `list` method.\r\n\r\n#### Code Sample\r\n\r\nHere is a code example:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# Create a mock dataframe\r\ndf = pd.DataFrame(data=[[1, 2, 1],[1, 2, 0]], columns=['a', 'b', 'c'])\r\n# filter it to be an empty dataframe\r\ndf = df[df['c']<0]\r\n# group to be multiIndexes and aggregate the groupby using the list method\r\ndf = df.groupby(['a','b']).agg(d=('c', list))\r\nprint(df.index)\r\n```\r\n\r\nThe output of this piece of code is:\r\n\r\n```\r\nIndex([], dtype='object')\r\n```\r\n\r\nand it should be:\r\n\r\n```\r\nMultiIndex([], names=['a', 'b'])\r\n```\r\n\r\n#### Problem description\r\n\r\nThis bug is happening only in the pandas' version 1.2.0, I've tried using versions 1.1.4 and 1.1.5, and the bug does not appear.\r\n\r\nIt is a very specific error that happens just when using MultiIndex, empty DataFrame, groupby, and aggregate using `list` method.\r\nIn this case, the indexes names will disappear, and the index will no longer be `MultiIndex` but `Index`.\r\n\r\n#### Expected Output\r\n\r\nThe output should be an empty dataframe multi indexed with the indexes names preserved.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\nFollows the ``pd.show_versions()``\r\n```\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-53-generic\r\nVersion          : #59-Ubuntu SMP Wed Oct 21 09:38:44 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : pt_BR.UTF-8\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.18.5\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 51.0.0\r\nCython           : 0.29.14\r\npytest           : 6.2.1\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6 (dt dec pq3 ext lo64)\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 0.8.5\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.3\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.5\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : 0.4.2\r\nscipy            : 1.6.0\r\nsqlalchemy       : 1.3.22\r\ntables           : None\r\ntabulate         : 0.8.7\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.52.0\r\n```\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39176',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39176/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39176/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39176/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39176',
#   'id': 786328824,
#   'node_id': 'MDU6SXNzdWU3ODYzMjg4MjQ=',
#   'number': 39176,
#   'title': 'CI: docs build failing?',
#   'user': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'},
#    {'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 78,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-15T14:12:37Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-01-14T20:48:04Z',
#   'updated_at': '2021-01-14T21:40:01Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'several recent PRs are showing a web / docs build failure: https://github.com/pandas-dev/pandas/pull/39136/checks?check_run_id=1704155153\r\n\r\nthough not sure we are actually seeing this on master.\r\n\r\ncc @pandas-dev/pandas-core ',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39175',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39175/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39175/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39175/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39175',
#   'id': 786168473,
#   'node_id': 'MDU6SXNzdWU3ODYxNjg0NzM=',
#   'number': 39175,
#   'title': 'CI: use conda incubator in doc build',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
# ...
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'},
#    {'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-13T14:10:00Z',
#   'updated_at': '2021-01-13T14:11:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Initial proof of concept for a non-consolidating "ArrayManager" (storing the columns of a DataFrame as a list of 1D arrays) is merged in https://github.com/pandas-dev/pandas/pull/36010.\r\n\r\nThis issue is meant to track the required follow-up work items to get this to a more feature-complete implementation.\r\n\r\n- **Functionality**: get all tests passing\r\n  - There are big chunks of tests failing because some larger sets of functionality is not yet implemented or relying on BlockManager internals (this last aspect is also covered in https://github.com/pandas-dev/pandas/issues/34669). Those bigger topics are:\r\n    - [ ] `quantile` / `describe` related (ArrayManager.quantile is not yet implemented)\r\n    - [ ] `equals` related (ArrayManager.equals is not yet implemented)\r\n    - [ ] `groupby` related tests (there are still a few parts of groupby that directly uses the blocks)\r\n    - [ ] `concat` related (`internals/concat.py` only deals with the simple case when no reindexing is needed for ArrayManager at the moment, the full functionality (similarly to what `concatenate_block_managers` / the `JoinUnits` now cover) still needs to be implemented)\r\n    - [ ] IO related (JSON and Stata code rely on block internals)\r\n  - In addition, the ArrayManager currently also uses an "apply_with_block" fallback for things that are right now implemented directly on the Block classes. Long term, all those cases should also be refactored so that the core functionality of the specific function can be shared between ArrayManager and BlockManager, without directly relying on the Block classes.\r\n    - [ ] Some examples of this: `replace`, `where`, `interpolate`, `shift`, `diff`, `downcast`, `putmask`, ... (those could all be refactored one at a time). \r\n  - There will also be tests that either are 1) BlockManager specific (using block internals to test) or 2) testing behaviour specific to DataFrames with BlockManager (we will probably want to change some aspects about eg copy/view, setitem-like ops, etc. Those changes all need to discussed separately of course, but might also require some skipped tests initially). \r\n    Such tests can be skipped with eg ``@td.skip_array_manager_invalid_test``.\r\n \r\n- **Design** questions:\r\n  - [ ] What to do with Series, which now is a SingleBlockManager inheriting from BlockManager (should we also have a "SingleArrayManager"?)\r\n  - [ ] ... (probably more items will come up) ...\r\n \r\n- **Performance**\r\n  - Currently, I didn\'t yet look at performance (I only ran a few of the ASV benchmarks, see top post of https://github.com/pandas-dev/pandas/pull/36010). I also think that we should first focus on getting a larger part of the functionality working (which will also make it easier to run benchmarks), but afterwards we will need to identify the different areas where performance improvements are needed. \r\n\r\n\r\n\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39144',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39144/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39144/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39144/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39144',
#   'id': 784814072,
#   'node_id': 'MDU6SXNzdWU3ODQ4MTQwNzI=',
#   'number': 39144,
#   'title': 'BUG: dataframe concatenation segementation fault (core dump)',
#   'user': {'login': 'stokhos',
#    'id': 19867532,
#    'node_id': 'MDQ6VXNlcjE5ODY3NTMy',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/19867532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stokhos',
#    'html_url': 'https://github.com/stokhos',
#    'followers_url': 'https://api.github.com/users/stokhos/followers',
#    'following_url': 'https://api.github.com/users/stokhos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stokhos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stokhos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stokhos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stokhos/orgs',
#    'repos_url': 'https://api.github.com/users/stokhos/repos',
#    'events_url': 'https://api.github.com/users/stokhos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stokhos/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2021-01-13T05:58:43Z',
#   'updated_at': '2021-01-13T15:16:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [ X ] I have checked that this issue has not already been reported.\r\n\r\n- [ X ] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\n    df = pd.concat(\r\n        (\r\n            pd.read_csv(os.path.join(dirpath, filename))\r\n            for dirpath, filename in file_generator\r\n        ),\r\n        ignore_index=True,\r\n    )\r\n\r\n\r\n```\r\n\r\n#### Problem description\r\n\r\nA subgroup of my files can cause the above function to break. And it happens 100% with those files with pandas1.2.0, with 1.1.5 no problem.\r\n\r\n[this should explain **why** the current behaviour is a problem and why the expected output is a better solution]\r\n\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n[paste the output of ``pd.show_versions()`` here leaving a blank line after the details tag]\r\n\r\n</details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.9.1.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.9.16-200.fc33.x86_64\r\nVersion          : #1 SMP Mon Dec 21 14:08:22 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.5\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.2.2\r\nsetuptools       : 49.1.3\r\nCython           : 0.29.21\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.5.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.18.1\r\npandas_datareader: 0.9.0\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.3\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.5.2\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.7\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39143',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39143/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39143/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39143/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39143',
#   'id': 784790283,
#   'node_id': 'MDU6SXNzdWU3ODQ3OTAyODM=',
#   'number': 39143,
#   'title': 'QST:Why DataFrame.pivot() will change the order of the rows of DataFrame?',
#   'user': {'login': 'jiahe224',
#    'id': 35186992,
#    'node_id': 'MDQ6VXNlcjM1MTg2OTky',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/35186992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jiahe224',
#    'html_url': 'https://github.com/jiahe224',
#    'followers_url': 'https://api.github.com/users/jiahe224/followers',
#    'following_url': 'https://api.github.com/users/jiahe224/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jiahe224/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jiahe224/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jiahe224/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jiahe224/orgs',
#    'repos_url': 'https://api.github.com/users/jiahe224/repos',
#    'events_url': 'https://api.github.com/users/jiahe224/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jiahe224/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-01-13T05:02:55Z',
#   'updated_at': '2021-01-14T07:20:44Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have searched the [[pandas] tag](https://stackoverflow.com/questions/tagged/pandas) on StackOverflow for similar questions.\r\n\r\n- [x] I have asked my usage related question on [StackOverflow](https://stackoverflow.com).\r\n\r\n---\r\n\r\n#### Question about pandas\r\n\r\n**Note**: If you'd still like to submit a question, please read [this guide](\r\nhttps://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your question.\r\n\r\n```python\r\n# Your code here, if applicable\r\n\r\n```\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39139',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39139/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39139/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39139/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39139',
#   'id': 784734759,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUzODc3NTEz',
#   'number': 39139,
#   'title': 'BUG: Placeholders not being filled on docstrings',
#   'user': {'login': 'MicaelJarniac',
#    'id': 19514231,
#    'node_id': 'MDQ6VXNlcjE5NTE0MjMx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/19514231?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MicaelJarniac',
#    'html_url': 'https://github.com/MicaelJarniac',
#    'followers_url': 'https://api.github.com/users/MicaelJarniac/followers',
#    'following_url': 'https://api.github.com/users/MicaelJarniac/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MicaelJarniac/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MicaelJarniac/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MicaelJarniac/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MicaelJarniac/orgs',
#    'repos_url': 'https://api.github.com/users/MicaelJarniac/repos',
#    'events_url': 'https://api.github.com/users/MicaelJarniac/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MicaelJarniac/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 15,
#   'created_at': '2021-01-13T02:29:00Z',
#   'updated_at': '2021-01-14T13:28:52Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39139',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39139',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39139.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39139.patch'},
#   'body': '- [x] closes #39115 \r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n',
#   'performed_via_github_app': None}]

# %%
issues=pd.DataFrame(data,columns=['number','title','label','state'])
issues
# Out:
#     number                                              title  label state
# 0    39189  BUG: queries on categorical string columns in ...    NaN  open
# 1    39188  REGR: Different results from DataFrame.apply a...    NaN  open
# 2    39186    REF: extract classes in pandas/core/describe.py    NaN  open
# 3    39185                DOC: set the documentation language    NaN  open
# 4    39184  BUG: Numpy np.[op](df1, df2) regression in pan...    NaN  open
# 5    39183                          January 2021 Docs Meeting    NaN  open
# 6    39182               CI/DOC: Add option to build whatsnew    NaN  open
# 7    39181  BUG: ExcelWriter.book --> no member ->Slow Exe...    NaN  open
# 8    39178  BUG: MultiIndexes are disappearing using an em...    NaN  open
# 9    39176                            CI: docs build failing?    NaN  open
# 10   39175               CI: use conda incubator in doc build    NaN  open
# 11   39174           CLN,TYP Remove string return annotations    NaN  open
# 12   39172  BUG: SeriesGroupBy.value_counts() raises on an...    NaN  open
# 13   39169  BUG: `df.agg` call passes different things to ...    NaN  open
# 14   39168  BUG: assert_frame_equal() with check_like=True...    NaN  open
# 15   39167  QST: Why is `storage_options` parameter missed...    NaN  open
# 16   39166  Pandas DataFrame with python own collection ap...    NaN  open
# 17   39164  ENH: add additional extras_require sections fo...    NaN  open
# 18   39163  API/BUG: always try to operate inplace when se...    NaN  open
# 19   39162  BUG: Calling tz_localize suppresses ValueError...    NaN  open
# 20   39159          ERR: Fix missing space in warning message    NaN  open
# 21   39158                             Minor typo on warnings    NaN  open
# 22   39155                   CI: Unreliable Tests write to S3    NaN  open
# 23   39154  ENH: Dedicated method for creating conditional...    NaN  open
# 24   39151  BUG: comparison of pandas NaT with datetime.da...    NaN  open
# 25   39148  BUG: Cells containing "NA" (string) in excel i...    NaN  open
# 26   39146             Refactor - ArrayManager overview issue    NaN  open
# 27   39144  BUG: dataframe concatenation segementation fau...    NaN  open
# 28   39143  QST:Why DataFrame.pivot() will change the orde...    NaN  open
# 29   39139   BUG: Placeholders not being filled on docstrings    NaN  open
